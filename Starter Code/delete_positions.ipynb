# %%
"""
Alpaca API - Liquidating positions

"""

import requests
import os
import json


API_KEY = os.getenv("ALPACA_API_KEY")
API_SECRET = os.getenv("ALPACA_SECRET_KEY")

endpoint = "https://paper-api.alpaca.markets"

headers = {'APCA-API-KEY-ID': API_KEY,
           'APCA-API-SECRET-KEY': API_SECRET}
'''
def market_order(symbol, quantity, side="buy", tif="day"):
    ord_url = endpoint + "/v2/orders"
    params = {"symbol": symbol,
              "qty": quantity,
              "side" : side,
              "type": "market",
              "time_in_force": tif}
    r = requests.post(ord_url, headers=headers, json=params)
    return r.json()
'''

def del_positions(symbol="", qty=0):
    if len(symbol)>1:
        pos_url = endpoint + "/v2/positions/{}".format(symbol)
        params = {"qty" : qty}
    else:
        pos_url = endpoint + "/v2/positions"
        params = {}
    r = requests.delete(pos_url, headers=headers, json=params)
    return r.json()

#market_order("CSCO", 10, "sell") #initiate a short position in CSCO
#market_order("GOOG", 2, "buy") #initiate a long position in GOOG
#market_order("INTC", 5, "buy") ##initiate a long position in INTC
#del_positions("CSCO") #delete CSCO position
del_positions() #delete all positions
# Out:
# [{'symbol': 'SPXU',
#   'status': 200,
#   'body': {'id': '9ff8b75c-d25f-4be7-b295-a84839fb8bfb',
#    'client_order_id': '3c73b097-a38a-4ba4-b8e0-61605eb8ccc1',
#    'created_at': '2022-09-23T13:47:41.172710889Z',
#    'updated_at': '2022-09-23T13:47:41.172771479Z',
#    'submitted_at': '2022-09-23T13:47:41.172323199Z',
#    'filled_at': None,
#    'expired_at': None,
#    'canceled_at': None,
#    'failed_at': None,
#    'replaced_at': None,
#    'replaced_by': None,
#    'replaces': None,
#    'asset_id': '5266b9ff-6a84-4d22-a3eb-dfe438d1e1e7',
#    'symbol': 'SPXU',
#    'asset_class': 'us_equity',
#    'notional': None,
#    'qty': '485',
#    'filled_qty': '0',
#    'filled_avg_price': None,
#    'order_class': '',
#    'order_type': 'market',
#    'type': 'market',
#    'side': 'sell',
#    'time_in_force': 'day',
#    'limit_price': None,
#    'stop_price': None,
#    'status': 'pending_new',
#    'extended_hours': False,
#    'legs': None,
#    'trail_percent': None,
#    'trail_price': None,
#    'hwm': None,
#    'subtag': None,
#    'source': None}},
#  {'symbol': 'SQQQ',
#   'status': 200,
#   'body': {'id': 'b49313e8-9fc6-4929-a301-a1d1fc8feedc',
#    'client_order_id': '7d38de07-f4d9-4f51-9bd1-6294c041741a',
#    'created_at': '2022-09-23T13:47:41.173195129Z',
#    'updated_at': '2022-09-23T13:47:41.173236159Z',
#    'submitted_at': '2022-09-23T13:47:41.172795159Z',
#    'filled_at': None,
#    'expired_at': None,
#    'canceled_at': None,
#    'failed_at': None,
#    'replaced_at': None,
#    'replaced_by': None,
#    'replaces': None,
#    'asset_id': 'eb8bb6f9-b4f1-4b57-8f7a-e577fcf07d4a',
#    'symbol': 'SQQQ',
#    'asset_class': 'us_equity',
#    'notional': None,
#    'qty': '93',
#    'filled_qty': '0',
#    'filled_avg_price': None,
#    'order_class': '',
#    'order_type': 'market',
#    'type': 'market',
#    'side': 'sell',
#    'time_in_force': 'day',
#    'limit_price': None,
#    'stop_price': None,
#    'status': 'pending_new',
#    'extended_hours': False,
#    'legs': None,
#    'trail_percent': None,
#    'trail_price': None,
#    'hwm': None,
#    'subtag': None,
#    'source': None}},
#  {'symbol': 'TQQQ',
#   'status': 200,
#   'body': {'id': 'ff6ef4d0-a2d6-43fb-ba6c-bf21be4369c7',
#    'client_order_id': '49fb3819-58d2-4105-8ca0-ae482d430667',
#    'created_at': '2022-09-23T13:47:41.173631649Z',
#    'updated_at': '2022-09-23T13:47:41.173662979Z',
#    'submitted_at': '2022-09-23T13:47:41.173262019Z',
#    'filled_at': None,
#    'expired_at': None,
#    'canceled_at': None,
#    'failed_at': None,
#    'replaced_at': None,
#    'replaced_by': None,
#    'replaces': None,
#    'asset_id': 'dce2ac30-c928-4416-be25-2213d057f30a',
#    'symbol': 'TQQQ',
#    'asset_class': 'us_equity',
#    'notional': None,
#    'qty': '221',
#    'filled_qty': '0',
#    'filled_avg_price': None,
#    'order_class': '',
#    'order_type': 'market',
#    'type': 'market',
#    'side': 'buy',
#    'time_in_force': 'day',
#    'limit_price': None,
#    'stop_price': None,
#    'status': 'pending_new',
#    'extended_hours': False,
#    'legs': None,
#    'trail_percent': None,
#    'trail_price': None,
#    'hwm': None,
#    'subtag': None,
#    'source': None}},
#  {'symbol': 'UPRO',
#   'status': 200,
#   'body': {'id': '56c55a5e-cfd3-41ab-a697-02e18fc91e82',
#    'client_order_id': 'ade1c9da-d129-4904-99c3-ba83255d5551',
#    'created_at': '2022-09-23T13:47:41.174103979Z',
#    'updated_at': '2022-09-23T13:47:41.174133299Z',
#    'submitted_at': '2022-09-23T13:47:41.173686909Z',
#    'filled_at': None,
#    'expired_at': None,
#    'canceled_at': None,
#    'failed_at': None,
#    'replaced_at': None,
#    'replaced_by': None,
#    'replaces': None,
#    'asset_id': 'e027f645-06ef-4794-80e6-5a0ab57f7607',
#    'symbol': 'UPRO',
#    'asset_class': 'us_equity',
#    'notional': None,
#    'qty': '150',
#    'filled_qty': '0',
#    'filled_avg_price': None,
#    'order_class': '',
#    'order_type': 'market',
#    'type': 'market',
#    'side': 'buy',
#    'time_in_force': 'day',
#    'limit_price': None,
#    'stop_price': None,
#    'status': 'pending_new',
#    'extended_hours': False,
#    'legs': None,
#    'trail_percent': None,
#    'trail_price': None,
#    'hwm': None,
#    'subtag': None,
#    'source': None}}]
